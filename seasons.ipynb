# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %%
df=pd.read_csv('weather-avg.csv')

# %%
df.head()
# Out:
#                                      meter_id  2017-01-01 00:00:00  \
# 0  0xa62b9f23553ff183f61e2bf943aab3d5983d02d7             4.904167
# 1  0xc53b26e7f9cc49e8131409db6e3bc47a2b7cee20             4.904167
# 2  0x99c6ba65bec5c1e83f8c19f6518178c87732c406             5.391667
# 3  0x8f04b8efaa48f13810f51e4b361961226d718ef1             5.250000
# 4  0x1a586297008785374c9de5073e7781d14d105bc8             5.370833
#
#    2017-01-02 00:00:00  2017-01-03 00:00:00  2017-01-04 00:00:00  \
# 0             1.275000             2.225000             4.266667
# 1             1.275000             2.225000             4.266667
# 2             1.550000             2.883333             4.691667
# 3             1.237500             2.287500             4.612500
# 4             1.529167             3.045833             4.341667
#
#    2017-01-05 00:00:00  2017-01-06 00:00:00  2017-01-07 00:00:00  \
# 0             0.262500             1.570833             7.833333
# 1             0.262500             1.570833             7.833333
# 2             0.729167             1.566667             7.650000
# 3             0.954167             1.791667             6.745833
# 4             0.670833             1.812500             6.745833
#
#    2017-01-08 00:00:00  2017-01-09 00:00:00  ...  2017-12-22 00:00:00  \
# 0             8.391667             6.904167  ...             8.666667
# 1             8.391667             6.904167  ...             8.666667
# 2             8.295833             7.345833  ...             8.695833
# 3             7.358333             6.908333  ...             8.195833
# 4             7.691667             6.841667  ...             8.612500
#
#    2017-12-23 00:00:00  2017-12-24 00:00:00  2017-12-25 00:00:00  \
# 0             8.370833             8.662500             9.645833
# 1             8.370833             8.662500             9.645833
# 2             8.595833             8.845833             9.591667
# 3             8.429167             8.712500             9.987500
# 4             7.983333             8.650000             9.841667
#
#    2017-12-26 00:00:00  2017-12-27 00:00:00  2017-12-28 00:00:00  \
# 0             4.008333             1.491667               0.5625
# 1             4.008333             1.491667               0.5625
# 2             4.545833             2.225000               1.2625
# 3             4.270833             2.529167               0.3375
# 4             4.187500             2.370833               1.1875
#
#    2017-12-29 00:00:00  2017-12-30 00:00:00  2017-12-31 00:00:00
# 0             2.925000             9.383333             9.462500
# 1             2.925000             9.383333             9.462500
# 2             3.308333             9.304167             9.708333
# 3             2.225000             8.462500             9.404167
# 4             1.908333             7.775000             9.270833
#
# [5 rows x 366 columns]

# %%
plt.figure(figsize=(20,10))
df.iloc[0,2:].plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
df.iloc[50,2:].plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
df.iloc[100,2:].plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
df.iloc[1000,2:].plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
df.iloc[2000,2:].plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
df.iloc[3000,2:].plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
for i in range(0,3000):
    df.iloc[i,2:].plot()
plt.show()
