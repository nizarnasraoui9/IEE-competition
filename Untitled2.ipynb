# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('QualityCover-results.csv')

# %%
df.head()
# Out:
#          Datasets Objects Attributes Concepts  Density  N Stress  M stress  \
# 0             apj   2,044      1,164      797    0.003     0.002     0.007
# 1  americas_large   3,485     10,127   36,990    0.005     0.003     0.009
# 2             DNA   4,590        392    4,482    0.015     0.013     0.034
# 3        customer  10,961        277   47,851    0.015     0.026     0.055
# 4  amercias_small   3,477      1,587    2,763    0.019     0.008     0.024
#
#    QualityCover  Gress  Cov =0.9  Cov =0.8  Cov =0.7  Cov =0.6  Cov =0.5
# 0           474  453.0       322       239       188       156       140
# 1           636    NaN       214       182       172       169       168
# 2           377  372.0       208       158       124       100        81
# 3           275  277.0       131       102        87        77        69
# 4           217  178.0        52        44        42        42        42

# %%
plt.scatter(df['N Stress'],df['QualityCover'],label='QualityCover')
plt.scatter(df['N Stress'],df['Gress'],label='Gress')
plt.legend()
plt.xlabel("N Stress")
# Out:
# Text(0.5, 0, 'N Stress')

# %%
plt.scatter(df['M stress'],df['QualityCover'],label='QualityCover')
plt.scatter(df['M stress'],df['Gress'],label='Gress')
plt.legend()
plt.xlabel("M stress")
# Out:
# Text(0.5, 0, 'M stress')

# %%
plt.scatter(df['Density'],df['QualityCover'],label='QualityCover')
plt.scatter(df['Density'],df['Gress'],label='Gress')
plt.legend()
plt.xlabel("Density")
# Out:
# Text(0.5, 0, 'Density')

# %%
plt.figure(figsize=(30,20))
plt.scatter(df['Concepts'],df['QualityCover'],label='QualityCover')
plt.scatter(df['Concepts'],df['Gress'],label='Gress')
plt.legend()
plt.xlabel("Concepts")
# Out:
# Text(0.5, 0, 'Concepts')

# %%
plt.figure(figsize=(30,20))
plt.scatter(df['Objects'],df['QualityCover'],label='QualityCover')
plt.scatter(df['Objects'],df['Gress'],label='Gress')
plt.legend()
plt.xlabel("Objects")
# Out:
# Text(0.5, 0, 'Objects')

# %%
plt.figure(figsize=(30,20))
plt.scatter(df['Attributes'],df['QualityCover'],label='QualityCover')
plt.scatter(df['Attributes'],df['Gress'],label='Gress')
plt.legend()
plt.xlabel("Attributes")
# Out:
# Text(0.5, 0, 'Attributes')

# %%
plt.figure(figsize=(20,10))
plt.scatter(df['N Stress'],df['QualityCover'],label='QualityCover')
plt.scatter(df['N Stress'],df['Cov =0.9'],label='Cov =0.9')
plt.scatter(df['N Stress'],df['Cov =0.8'],label='Cov =0.8')
plt.scatter(df['N Stress'],df['Cov =0.7'],label='Cov =0.7')
plt.scatter(df['N Stress'],df['Cov =0.6'],label='Cov =0.6')
plt.scatter(df['N Stress'],df['Cov =0.5'],label='Cov =0.5')
plt.legend()
plt.xlabel("Attributes")
# Out:
# Text(0.5, 0, 'Attributes')

# %%
plt.figure(figsize=(20,10))
plt.scatter(df['M stress'],df['QualityCover'],label='QualityCover')
plt.scatter(df['M stress'],df['Cov =0.9'],label='Cov =0.9')
plt.scatter(df['M stress'],df['Cov =0.8'],label='Cov =0.8')
plt.scatter(df['M stress'],df['Cov =0.7'],label='Cov =0.7')
plt.scatter(df['M stress'],df['Cov =0.6'],label='Cov =0.6')
plt.scatter(df['M stress'],df['Cov =0.5'],label='Cov =0.5')
plt.legend()
plt.xlabel('M stress')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.scatter(df['Density'],df['QualityCover'],label='QualityCover')
plt.scatter(df['Density'],df['Cov =0.9'],label='Cov =0.9')
plt.scatter(df['Density'],df['Cov =0.8'],label='Cov =0.8')
plt.scatter(df['Density'],df['Cov =0.7'],label='Cov =0.7')
plt.scatter(df['Density'],df['Cov =0.6'],label='Cov =0.6')
plt.scatter(df['Density'],df['Cov =0.5'],label='Cov =0.5')
plt.legend()
plt.xlabel('Density')
plt.show()

# %%
plt.figure(figsize=(30,20))
plt.scatter(df['Concepts'],df['QualityCover'],label='QualityCover')
plt.scatter(df['Concepts'],df['Cov =0.9'],label='Cov =0.9')
plt.scatter(df['Concepts'],df['Cov =0.8'],label='Cov =0.8')
plt.scatter(df['Concepts'],df['Cov =0.7'],label='Cov =0.7')
plt.scatter(df['Concepts'],df['Cov =0.6'],label='Cov =0.6')
plt.scatter(df['Concepts'],df['Cov =0.5'],label='Cov =0.5')
plt.legend()
plt.xlabel('Concepts')
plt.show()

# %%
plt.figure(figsize=(30,20))
plt.scatter(df['Objects'],df['QualityCover'],label='QualityCover')
plt.scatter(df['Objects'],df['Cov =0.9'],label='Cov =0.9')
plt.scatter(df['Objects'],df['Cov =0.8'],label='Cov =0.8')
plt.scatter(df['Objects'],df['Cov =0.7'],label='Cov =0.7')
plt.scatter(df['Objects'],df['Cov =0.6'],label='Cov =0.6')
plt.scatter(df['Objects'],df['Cov =0.5'],label='Cov =0.5')
plt.legend()
plt.xlabel('Objects')
plt.show()

# %%
plt.figure(figsize=(30,20))
plt.scatter(df['Attributes'],df['QualityCover'],label='QualityCover')
plt.scatter(df['Attributes'],df['Cov =0.9'],label='Cov =0.9')
plt.scatter(df['Attributes'],df['Cov =0.8'],label='Cov =0.8')
plt.scatter(df['Attributes'],df['Cov =0.7'],label='Cov =0.7')
plt.scatter(df['Attributes'],df['Cov =0.6'],label='Cov =0.6')
plt.scatter(df['Attributes'],df['Cov =0.5'],label='Cov =0.5')
plt.legend()
plt.xlabel('Attributes')
plt.show()

# %%
plt.figure()
print("color: M Stress")
x=df['M stress'].values.tolist()
y=df['QualityCover'].values.tolist()
z=df['N Stress'].tolist()
plt.scatter(x,y,c=z)
plt.xlabel("M stress")
plt.ylabel("Quality Cover")
plt.colorbar()
plt.show()
# Out:
# color: M Stress

# %%
plt.figure()
print("color: M Stress")
x=df['M stress'].values.tolist()
y=df['Gress'].values.tolist()
z=df['N Stress'].tolist()
plt.scatter(x,y,c=z)
plt.xlabel("M stress")
plt.ylabel("Gress")
plt.colorbar()
plt.show()
# Out:
# color: M Stress

# %%
plt.figure()
print("color: M Stress")
x=df['Density'].values.tolist()
y=df['QualityCover'].values.tolist()
z=df['N Stress'].tolist()
plt.scatter(x,y,c=z)
plt.xlabel("Density")
plt.ylabel("QualityCover")
plt.colorbar()
plt.show()
# Out:
# color: M Stress

# %%
plt.figure()
print("color: M Stress")
x=df['Density'].values.tolist()
y=df['Gress'].values.tolist()
z=df['N Stress'].tolist()
plt.scatter(x,y,c=z)
plt.xlabel("Density")
plt.ylabel("Gress")
plt.colorbar()
plt.show()
# Out:
# color: M Stress

# %%
plt.figure()
print("color: N stress")
x=df['Density'].values.tolist()
y=df['Gress'].values.tolist()
z=df['N Stress'].tolist()
plt.scatter(x,y,c=z)
plt.xlabel("Density")
plt.ylabel("Gress")
plt.colorbar()
plt.show()
# Out:
# color: N stress

# %%
plt.figure()
print("color: N Stress")
x=df['Density'].values.tolist()
y=df['QualityCover'].values.tolist()
z=df['N Stress'].tolist()
plt.scatter(x,y,c=z)
plt.xlabel("Density")
plt.ylabel("QualityCover")
plt.colorbar()
plt.show()
# Out:
# color: N Stress
